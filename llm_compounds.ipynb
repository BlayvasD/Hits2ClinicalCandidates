# %%
# !pip install --upgrade ipywidgets jupyterlab
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 17.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 65.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: jupyterlab-server0m━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [ipywidgets]widgets]
#     Found existing installation: jupyterlab_server 2.27.3━━━━━ 2/5 [ipywidgets]
#     Uninstalling jupyterlab_server-2.27.3:━━━━━━━━━━━━━━━ 3/5 [jupyterlab-server]
#       Successfully uninstalled jupyterlab_server-2.27.3━━━━━━━ 3/5 [jupyterlab-server]
#    ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━ 3/5 [jupyterlab-server]

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, GenerationConfig

model_name_or_id = "../models/ChemDFM-v1.5-8B"
cache_path = "../models/"
# tokenizer = LlamaTokenizer.from_pretrained(model_name_or_id)
# model = LlamaForCausalLM.from_pretrained(model_name_or_id, torch_dtype=torch.float16, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(model_name_or_id, cache_dir=cache_path, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(model_name_or_id, cache_dir=cache_path, trust_remote_code=True, dtype=torch.float16, device_map="auto")
# Out:
# Loading checkpoint shards: 100%|██████████████████████████████████████████████████████████| 4/4 [03:34<00:00, 53.61s/it]

# %%
from transformers import TextIteratorStreamer
import threading

# ----- Test prompt -----
prompt = "My favorite biological molecule and why it's my favorite is"

inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

# ----- Streaming setup -----
streamer = TextIteratorStreamer(tokenizer, skip_special_tokens=True)

thread = threading.Thread(
    target=lambda: model.generate(
        **inputs,
        max_new_tokens=256,
        do_sample=True,
        temperature=0.7,
        streamer=streamer
    )
)
thread.start()

# ----- Stream output -----
for chunk in streamer:
    print(chunk, end="", flush=True)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# My favorite biological molecule and why it's my favorite is because of its ability to function as an antioxidant. I am a big fan of antioxidants and their ability to protect cells from damage caused by free radicals. vitamins C and E are both powerful antioxidants that can help prevent cell damage and promote overall health. Vitamins C and E work together to neutralize free radicals, which are unstable molecules that can cause harm to cells. Vitamins C and E also have anti-inflammatory properties, which can help reduce inflammation in the body and promote healing.
# So, my favorite biological molecule is vitamin C because of its powerful antioxidant properties and its ability to promote overall health and wellness.
